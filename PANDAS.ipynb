# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load your dataset
df= pd.read_csv('onlinefoods.csv',encoding="latin-1")

# %%
df.sample(5)
# Out:
#      Age  Gender     Marital Status Occupation   Monthly Income  \
# 199   23  Female             Single    Student        No Income
# 161   26    Male             Single   Employee  More than 50000
# 90    27  Female  Prefer not to say   Employee   25001 to 50000
# 180   29  Female            Married   Employee  More than 50000
# 309   23    Male             Single    Student   Below Rs.10000
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 199                   Graduate            2   13.0298    77.6047    560032
# 161              Post Graduate            3   12.9337    77.5900    560011
# 90               Post Graduate            5   13.0289    77.5400    560022
# 180                   Graduate            3   12.9570    77.5637    560018
# 309              Post Graduate            2   12.9770    77.5773    560009
#
#     Output   Feedback Unnamed: 12
# 199     No  Negative           No
# 161     No  Negative           No
# ...

# %%
df.sample(4)
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 6     22    Male         Single    Student       No Income
# 196   19    Male         Single    Student       No Income
# 286   25  Female         Single    Student  10001 to 25000
# 314   24    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 6                     Graduate            3   12.9770    77.5773    560009
# 196                   Graduate            6   12.9442    77.6076    560030
# 286                   Graduate            2   12.9757    77.5586    560023
# 314              Post Graduate            2   12.9706    77.6529    560075
#
#     Output  Feedback Unnamed: 12
# 6      Yes  Positive         Yes
# 196    Yes  Positive         Yes
# 286    Yes  Positive         Yes
# 314    Yes  Positive         Yes

# %%
df.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
df.tail()
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 383              Post Graduate            2   12.9766    77.5993    560001
# 384              Post Graduate            4   12.9854    77.7081    560048
# 385              Post Graduate            5   12.9850    77.5533    560010
# 386              Post Graduate            2   12.9770    77.5773    560009
# 387              Post Graduate            5   12.8988    77.5764    560078
#
#     Output  Feedback Unnamed: 12
# 383    Yes  Positive         Yes
# 384    Yes  Positive         Yes
# 385    Yes  Positive         Yes
# ...

# %% [markdown]
# INSIGHTS

# %%
males  peoples orderd more than femlae people
here singles are order more food than married people
23 age peoples are order more than 22
all the peoples are  giving  a positive feedback

# %%
df
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
 x=df ["Marital Status"]
x
# Out:
# 0      Single
# 1      Single
# 2      Single
# 3      Single
# 4      Single
#         ...
# 383    Single
# 384    Single
# 385    Single
# 386    Single
# 387    Single
# Name: Marital Status, Length: 388, dtype: object

# %%
x=df["Gender"]
x
# Out:
# 0      Female
# 1      Female
# 2        Male
# 3      Female
# 4        Male
#         ...
# 383    Female
# 384    Female
# 385    Female
# 386      Male
# 387      Male
# Name: Gender, Length: 388, dtype: object

# %%
x=df["Family size"]

# %%
x
# Out:
# 0      4
# 1      3
# 2      3
# 3      6
# 4      4
#       ..
# 383    2
# 384    4
# 385    5
# 386    2
# 387    5
# Name: Family size, Length: 388, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'latitude', 'longitude',
#        'Pin code', 'Output', 'Feedback', 'Unnamed: 12'],
#       dtype='object')

# %%
x=df["Occupation"]
x
# Out:
# 0      Student
# 1      Student
# 2      Student
# 3      Student
# 4      Student
#         ...
# 383    Student
# 384    Student
# 385    Student
# 386    Student
# 387    Student
# Name: Occupation, Length: 388, dtype: object

# %%
x=df["latitude"]
x
# Out:
# 0      12.9766
# 1      12.9770
# 2      12.9551
# 3      12.9473
# 4      12.9850
#         ...
# 383    12.9766
# 384    12.9854
# 385    12.9850
# 386    12.9770
# 387    12.8988
# Name: latitude, Length: 388, dtype: float64

# %%
df.iloc[100]
# Out:
# Age                                       24
# Gender                                Female
# Marital Status                        Single
# Occupation                           Student
# Monthly Income                10001 to 25000
# Educational Qualifications     Post Graduate
# Family size                                3
# latitude                             12.9335
# longitude                            77.5691
# Pin code                              560028
# Output                                    No
# Feedback                            Positive
# Unnamed: 12                               No
# Name: 100, dtype: object
